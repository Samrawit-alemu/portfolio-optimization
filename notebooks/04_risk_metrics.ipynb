# %%
import sys

sys.path.append("../")

import pandas as pd

from src.metrics import *

tickers=["TSLA","BND","SPY"]

for ticker in tickers:

    df=pd.read_csv(f"../data/processed/{ticker}.csv")

    df=calculate_returns(df)

    print(ticker)

    print("Sharpe Ratio:",sharpe_ratio(df))

    print("VaR:",value_at_risk(df))
